# %%
# !uv pip install numba==0.56.4  matplotlib==3.8.0 networkx==3.1 numpy==1.23.5 pandas==2.1.4 scikit-learn==1.3.0 scipy==1.11.4 seaborn==0.12.2 ortools==9.8.3296 gdown tigramite torch
# Out:
# ⠹ mpmath==1.3.0                                                                 Resolved 45 packages in 263ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)----     0 B/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 16.00 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 32.00 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 48.00 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 63.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 79.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 95.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 111.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 127.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 143.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 159.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 175.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 191.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 207.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 223.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 239.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 255.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 271.19 KiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 1.28 MiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 2.34 MiB/65.38 MiB
# ⠹ Preparing packages... (0/1)---- 3.48 MiB/65.38 MiB
# ⠹ Preparing packages... (0/1)---- 5.36 MiB/65.38 MiB
# ⠹ Preparing packages... (0/1)---- 6.95 MiB/65.38 MiB
# ⠹ Preparing packages... (0/1)---- 7.83 MiB/65.38 MiB
# ⠸ Preparing packages... (0/1)---- 8.62 MiB/65.38 MiB
# ⠸ Preparing packages... (0/1)---- 9.29 MiB/65.38 MiB
# ⠸ Preparing packages... (0/1)---- 9.67 MiB/65.38 MiB
# ⠸ Preparing packages... (0/1)---- 9.89 MiB/65.38 MiB
# ⠼ Preparing packages... (0/1)---- 10.08 MiB/65.38 MiB
# ⠼ Preparing packages... (0/1)---- 10.32 MiB/65.38 MiB
# ⠼ Preparing packages... (0/1)---- 10.56 MiB/65.38 MiB
# ⠼ Preparing packages... (0/1)---- 10.79 MiB/65.38 MiB
# ⠴ Preparing packages... (0/1)---- 11.00 MiB/65.38 MiB
# ⠴ Preparing packages... (0/1)---- 11.23 MiB/65.38 MiB
# ⠴ Preparing packages... (0/1)---- 11.39 MiB/65.38 MiB
# ⠴ Preparing packages... (0/1)---- 11.62 MiB/65.38 MiB
# ⠦ Preparing packages... (0/1)---- 11.78 MiB/65.38 MiB
# ⠦ Preparing packages... (0/1)---- 11.98 MiB/65.38 MiB
# ⠦ Preparing packages... (0/1)---- 12.23 MiB/65.38 MiB
# ⠦ Preparing packages... (0/1)---- 12.48 MiB/65.38 MiB
# ⠧ Preparing packages... (0/1)---- 12.67 MiB/65.38 MiB
# ⠧ Preparing packages... (0/1)---- 12.90 MiB/65.38 MiB
# ⠧ Preparing packages... (0/1)---- 13.14 MiB/65.38 MiB
# ⠧ Preparing packages... (0/1)---- 13.36 MiB/65.38 MiB
# ⠇ Preparing packages... (0/1)---- 13.90 MiB/65.38 MiB
# ⠇ Preparing packages... (0/1)---- 14.53 MiB/65.38 MiB
# ⠇ Preparing packages... (0/1)---- 14.82 MiB/65.38 MiB
# ⠇ Preparing packages... (0/1)---- 15.61 MiB/65.38 MiB
# ⠋ Preparing packages... (0/1)---- 17.81 MiB/65.38 MiB
# ⠋ Preparing packages... (0/1)---- 20.69 MiB/65.38 MiB
# ⠋ Preparing packages... (0/1)---- 22.66 MiB/65.38 MiB
# ⠋ Preparing packages... (0/1)---- 24.64 MiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 26.75 MiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 29.03 MiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 31.08 MiB/65.38 MiB
# ⠙ Preparing packages... (0/1)---- 32.91 MiB/65.38 MiB
# ⠹ Preparing packages... (0/1)---- 35.22 MiB/65.38 MiB
# ⠹ Preparing packages... (0/1)---- 37.17 MiB/65.38 MiB
# ⠹ Preparing packages... (0/1)---- 38.81 MiB/65.38 MiB
# ⠹ Preparing packages... (0/1)---- 40.95 MiB/65.38 MiB
# ⠸ Preparing packages... (0/1)---- 42.73 MiB/65.38 MiB
# ⠸ Preparing packages... (0/1)---- 44.98 MiB/65.38 MiB
# ⠸ Preparing packages... (0/1)---- 47.53 MiB/65.38 MiB
# ⠸ Preparing packages... (0/1)---- 49.20 MiB/65.38 MiB
# ⠼ Preparing packages... (0/1)---- 50.58 MiB/65.38 MiB
# ⠼ Preparing packages... (0/1)---- 51.36 MiB/65.38 MiB
# ⠼ Preparing packages... (0/1)---- 52.23 MiB/65.38 MiB
# ⠼ Preparing packages... (0/1)---- 53.00 MiB/65.38 MiB
# ⠴ Preparing packages... (0/1)---- 54.98 MiB/65.38 MiB
# ⠴ Preparing packages... (0/1)m--- 57.73 MiB/65.38 MiB
# ⠴ Preparing packages... (0/1)2m-- 60.02 MiB/65.38 MiB
# ⠴ Preparing packages... (0/1)- 61.06 MiB/65.38 MiB
# ⠦ Preparing packages... (0/1)- 61.64 MiB/65.38 MiB
# ⠦ Preparing packages... (0/1)- 62.45 MiB/65.38 MiB
# ⠦ Preparing packages... (0/1) 63.23 MiB/65.38 MiB
# Prepared 1 package in 2.95s
# Installed 6 packages in 404ms
#  + fsspec==2025.3.2
#  + jinja2==3.1.6
#  + markupsafe==3.0.2
#  + mpmath==1.3.0
#  + sympy==1.13.3
#  + torch==2.7.0

# %%
# imports
import copy

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Data manipulation
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from datetime import datetime, timedelta

# Metrics and Evaluation
from sklearn.metrics import confusion_matrix

# %%
# Data preprocessing and graph visualization
from tigramite import data_processing as pp
from tigramite import plotting as tp
# Causal discovery
from tigramite.independence_tests.parcorr import ParCorr
from tigramite.independence_tests.robust_parcorr import RobustParCorr
from tigramite.pcmci import PCMCI
from tigramite.models import Models
# from rpcmci import RPCMCI
import networkx as nx
# Linear model
from sklearn.linear_model import LinearRegression
import torch
import torch.nn as nn

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cpu

# %%
def reshape_and_resample_df(filename, val_type='seasonal_dtr_val_std', sample_freq='3D', sampling_type='mean',
                            fill_missing=False, fill_missing_value=999., use_evap=False):
    # Load DataFrame
    df = pd.read_csv(filename)
    freq = int(sample_freq[0])

    # Convert 'VAC' values
    vac_conversion = {'a': 1, 'b': 2, 'c': 3, 'd': 4, '0': 0}
    df['VAC'] = df['VAC'].replace(vac_conversion).astype(float)

    # Pivot the DataFrame
    pivoted_df = df.pivot(index='date', columns='var', values=val_type)
    pivoted_df.index = pd.to_datetime(pivoted_df.index)

    # only keep years starting from 1990
    # all_days_to_keep = np.arange(datetime(1993, 3, 1), datetime(2022, 9, 30),
    #                              timedelta(days=1)).astype(datetime)
    all_days_to_keep = np.arange(datetime(1950, 3, 1), datetime(2022, 9, 30),
                                 timedelta(days=1)).astype(datetime)
    dates_to_keep = [i for i in all_days_to_keep if i in pivoted_df.index]
    pivoted_df = pivoted_df.loc[dates_to_keep]

    if use_evap:
        pivoted_df['evap'] = pivoted_df['slhf'] / pivoted_df['slhf'] + \
        pivoted_df['sshf']

    # Extract and prepare 'VAC' column
    date_to_vac = df.drop_duplicates(subset='date').set_index('date')['VAC']
    date_to_vac.index = pd.to_datetime(date_to_vac.index)
    date_to_vac = date_to_vac.loc[dates_to_keep]

    if fill_missing:
        date_array = pivoted_df.index

        # fill in missing days with 999.
        filled_df = pd.DataFrame(fill_missing_value, index=all_days_to_keep,
                                 columns=pivoted_df.columns)
        filled_df.index = pd.to_datetime(filled_df.index).strftime('%Y-%m-%d')

        filled_vac_df = pd.Series(fill_missing_value, index=all_days_to_keep)
        filled_vac_df.index = pd.to_datetime(
            filled_vac_df.index).strftime('%Y-%m-%d')

        for day in filled_df.index:
            if day in date_array:
                filled_df.loc[day] = pivoted_df.loc[day]
                filled_vac_df.loc[day] = date_to_vac.loc[day]

        pivoted_df = filled_df
        date_to_vac = filled_vac_df

    # Resample data
    if sampling_type == 'mean':
        resampled = pivoted_df.copy().resample(sample_freq).mean().dropna()
        resampled_vac = np.round(
            date_to_vac.resample(sample_freq).median().dropna())
    elif sampling_type == 'subsample':
        # Assuming 'sample_freq' contains a valid integer for frequency
        resampled = pivoted_df.copy().iloc[::freq]
        resampled_vac = date_to_vac.iloc[::freq]
    else:
        raise ValueError('This type of sampling is not supported!')

    # Assign 'VAC' values to the resampled DataFrame
    resampled['VAC'] = resampled_vac

    return resampled

# %%
def get_pandas_and_tigramite_dfs(filename, val_type='seasonal_dtr_val_std', sample_freq='1D', sampling_type='mean',
                                 vals_to_drop=None, fill_missing=False, fill_missing_value=999., use_evap=False):
    # Reshape and resample DataFrame
    pd_df = reshape_and_resample_df(filename, val_type=val_type,
                                    sample_freq=sample_freq,
                                    sampling_type=sampling_type,
                                    fill_missing=fill_missing,
                                    fill_missing_value=fill_missing_value,
                                    use_evap=use_evap)

    vac_values = pd_df['VAC'].copy().to_numpy()

    # rename columns
    pd_df = pd_df.rename(columns={'slhf': 'LH',
                                  'sshf': 'SH',
                                  'swvl123': 'SM',
                                  't2m': 'T2m',
                                  'tp': 'TP',
                                  'stream': 'Stream',
                                  'ssrd': 'SW'})

    # Drop specified columns if provided
    if vals_to_drop is not None:
        pd_df.drop(vals_to_drop, axis=1, inplace=True)
    
    # Sort the DataFrame by index
    pd_df.sort_index(inplace=True)

    # Convert to new DataFrame with appropriate column names
    tig_df = pp.DataFrame(pd_df.to_numpy(), var_names=pd_df.columns, missing_flag=999.)

    return pd_df, tig_df, vac_values

# %% [markdown]
# - Mean air temperature 2m above the ground (T2m),
# - Root-zone (1m) soil moisture (SM),
# - Surface sensible heat flux (SH), sign swapped to obtain positive upward fluxes,
# - Surface latent heat flux (LH), sign swapped as for SH,
# - Stream function at 250 hPa (Stream), describing atmospheric circulation patterns,
# - Shortwave downward radiation (SW),
# - Precipitation (TP),
# - An expert guided regime classification index, i.e. the vegetation-atmosphere coupling (VAC) index (https://doi.org/10.1002/2015GL066563) based on the co-occcurence of soil moisture and temperature anomalies using thresholding (See Figure below, left panel a).

# %%
filled_pd_df, filled_tigramite_df, filled_vac_values = get_pandas_and_tigramite_dfs(
    './LAF_WWCE_SM_VAC_dtr_std_MAMJJAS.csv',
    sampling_type='subsample',
    sample_freq='1D',
    vals_to_drop=['swvl2', 'swvl3', 'swvl1', 'VAC'],
    fill_missing=True, fill_missing_value=999., use_evap=False)

filled_pd_df
# Out:
# var               LH        SH        SW    Stream        SM       T2m  \
# 1950-03-01 -2.154144 -0.125094 -1.410969 -1.501948  1.432580 -2.886783
# 1950-03-02 -2.160544 -0.208967 -1.129304 -0.910112  1.389200 -2.790230
# 1950-03-03 -2.111713 -0.631610 -1.046753 -0.414591  1.349157 -2.440718
# 1950-03-04 -2.374583 -1.691506 -1.905727 -0.138127  1.324861 -1.912801
# 1950-03-05 -2.263274 -1.272122 -1.444837  0.427211  1.315524 -1.638096
# ...              ...       ...       ...       ...       ...       ...
# 2022-09-25 -1.214774 -1.058357 -1.717759  0.064268 -0.898910 -0.458938
# 2022-09-26 -0.845842 -1.899847 -1.889848  0.142732 -0.828307 -0.601944
# 2022-09-27 -0.558362 -2.052421 -1.912754  0.041978 -0.701472 -0.763503
# 2022-09-28 -1.189397 -2.025593 -2.225434 -0.266826 -0.527653 -0.845023
# 2022-09-29 -1.387368 -1.006228 -1.699652 -0.487880 -0.431604 -0.947631
#
# var               TP
# 1950-03-01 -0.766967
# 1950-03-02 -0.918155
# 1950-03-03 -0.943481
# 1950-03-04 -0.763066
# 1950-03-05 -0.933555
# ...              ...
# 2022-09-25  0.744294
# 2022-09-26  1.147305
# 2022-09-27  2.186342
# 2022-09-28  2.473897
# 2022-09-29  0.627608
#
# [26511 rows x 7 columns]

# %%
# Set hyperparameters
tau_min = 1
tau_max = 5
# pc_alpha = None
# alpha_level = 0.01

pcmci = PCMCI(dataframe=filled_tigramite_df,
              cond_ind_test=RobustParCorr())

pcmci_results = pcmci.run_pcmci(tau_min=tau_min, tau_max=tau_max)#, pc_alpha=pc_alpha, alpha_level=alpha_level)

tp.plot_graph(val_matrix=pcmci_results['val_matrix'],
              graph=pcmci_results['graph'], var_names=filled_tigramite_df.var_names,
              node_aspect=0.5, node_size=0.5
              )
plt.show()

# %%
model = Models(
    dataframe=filled_tigramite_df,
    model=RandomForestRegressor(),
)
all_parents = pcmci.return_parents_dict(pcmci_results["graph"], pcmci_results["val_matrix"])
model.fit_full_model(all_parents)

# %%
nets = {}
hist = {}
for i, parents in all_parents.items():
    X = []
    Y = [(i, 0)]
    Z = parents
    arr = filled_tigramite_df.construct_array(
        X=X, Y=Y, Z=Z,
        tau_max=tau_max,
        mask_type=None,
        cut_off="2xtau_max",
        remove_overlaps=True,
        verbosity=False
    )
    data = torch.from_numpy(arr[0]).float().to(device)
    y_true = data[0]     # shape (T,)
    X_data = data[1:].T  # shape (T, num_parents)

    # define a tiny 1-hidden-layer network
    net = nn.Sequential(
        nn.Linear(X_data.size(1), 4),
        nn.ReLU(),
        nn.Linear(4, 1)
    ).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

    # train for a few epochs
    losses = []
    for epoch in range(100):
        net.train()
        optimizer.zero_grad()
        y_pred = net(X_data).squeeze()       # shape (T,)
        loss = criterion(y_pred, y_true)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    nets[i] = net
    hist[i] = losses

# %%
y_trues = []
for i in range(len(all_parents)):
    Y = [(i, 0)]
    X = []
    Z = all_parents[i] # ensure the resulting y_true matches the length of the predicted values
    arr = filled_tigramite_df.construct_array(X, Y, Z,
                                    tau_max=tau_max,
                                    mask_type=None,
                                    cut_off="2xtau_max",
                                    remove_overlaps=True,
                                    verbosity=False)
    y_true = arr[0][0, :]
    y_trues.append(y_true)

# %%
predictions = model.predict_full_model(cut_off="2xtau_max",)

# %%
rmse = {}
for i, net in nets.items():
    # re-construct inputs exactly as above (or reuse X_data from training)
    Y = [(i, 0)]
    Z = all_parents[i]
    arr = filled_tigramite_df.construct_array(
        X=[], Y=Y, Z=Z,
        tau_max=tau_max,
        mask_type=None,
        cut_off="2xtau_max",
        remove_overlaps=True,
        verbosity=False
    )
    data = torch.from_numpy(arr[0]).float().to(device)
    y_true = data[0]
    X_data = data[1:].T

    net.eval()
    with torch.no_grad():
        y_pred = net(X_data).squeeze()
    rmse[i] = torch.sqrt(((y_pred - y_true)**2).mean()).item()

# print out
for i, score in rmse.items():
    print(f"Variable {filled_pd_df.columns[i]}:  RMSE = {score:.4f}")
# Out:
# Variable LH:  RMSE = 1.1576
# Variable SH:  RMSE = 0.9650
# Variable SW:  RMSE = 0.9759
# Variable Stream:  RMSE = 1.1630
# Variable SM:  RMSE = 0.9730
# Variable T2m:  RMSE = 0.9233
# Variable TP:  RMSE = 1.0461

# %%
# compute RMSE for each variable
for i in range(len(predictions)):
    print(f"RMSE for variable {filled_pd_df.columns[i]}: {np.sqrt(np.mean((predictions[i] - y_trues[i]) ** 2))}")
# Out:
# RMSE for variable LH: 0.32557686081668086
# RMSE for variable SH: 0.5719274669490494
# RMSE for variable SW: 0.5045686904965971
# RMSE for variable Stream: 0.2207405388023029
# RMSE for variable SM: 0.030213213753364755
# RMSE for variable T2m: 0.18967788464360932
# RMSE for variable TP: 0.8038609701128868

# %%
# compute RMSE for each variable
for i in range(len(predictions)):
    print(f"RMSE for variable {filled_pd_df.columns[i]}: {np.sqrt(np.mean((predictions[i] - y_trues[i]) ** 2))}")
